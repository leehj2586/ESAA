# %% [markdown]
# <a href="https://colab.research.google.com/github/leehj2586/leehj/blob/main/ESAA_1014_%ED%8C%8C%EB%A8%B8%EC%99%849%EC%9E%A5_%EC%B6%94%EC%B2%9C%EC%8B%9C%EC%8A%A4%ED%85%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 파이썬 머신러닝 완벽가이드 개정2판 9장 p.584-601

# %% [markdown]
# # Chapter 9. 추천시스템

# %% [markdown]
# ## 01. 추천 시스템의 개요와 배경
# ### 온라인 스토어의 필수 요소, 추천시스템

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 추천 시스템의 유형
# - 콘텐츠 기반 필터링
# - 협업 필터링
#     - 최근접 이웃 협업 필터링
#     - 잠재 요인 협업 필터링
#
# -> 하이브리드 형식으로 콘텐츠 기반과 협업 기반을 적절히 결합하는 경우도 증가중

# %% [markdown]
# ## 02. 콘텐츠 기반 필터링 추천 시스템
# : 사용자가 특정 아이템을 선호하는 경우, 그 아이템과 비슷한 콘텐츠를 가진 다른 아이템 추천하는 방식

# %% [markdown]
# ## 03. 최근접 이웃 협업 필터링
# - 협업 필터링: 사용자의 행동양식만을 기반으로 추천 수행
# ![image.png](data:image/png;base64,...)
#     - 목표: 사용자가 평가한 다른 아이템을 기반으로 사용자가 평가하지 않은 아이템의 예측 평가
#     - 사용자 - 아이템 평점 행렬 데이터에만 의지해 추천 수행
#         - 행: 개별 사용자
#         - 열: 개별 아이템
#         - 행과 열에 해당하는 값: 평점
#         - 아이템 ↑, 평점 ↓ => 희소행렬 특성 O
#
#     1. 최근접 이웃 방식(=메모리 협업 필터링)
#         - 사용자 기반: 비슷한 사용자의 구매 아이템 추천
#
# ![image.png](data:image/png;base64,...)
#
# - 아이템 기반: 해당 상품 고른 고객들의 다음 구매 상품 추천
#     -> 대부분 아이템 기반 알고리즘 적용
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 04. 잠재요인 협업 필터링
# ### 잠재 요인 협업 필터링의 이해
# : 잠재요인 기반으로 다차원 희소 행렬인 사용자 - 아이템 행렬 데이터
# → 저차원 밀집 행렬의 사용자- 잠재요인 행렬 + 아이템-잠재요인 행렬의 전치 행렬로 분해 가능
# - 평점: 사용자의 특정 영화 장르에 대한 선호도 + 개별 영화의 그 장르적 특성값을 반영하여 결정

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 행렬 분해의 이해
# : 다차원의 매트릭스를 저차원 매트릭스로 분해
# - 대표적 기법
#     - SVD Singular Vector Decomposition
#     - NNMF Non Negative Matrix Factorization
# - M개의 사용자 행과 N개의 아이템 열을 가진 평점행렬 R
# - 사용자 - K 차원의 잠재요인 행렬 P
# - K 차원 잠재요인 - 아이템 행렬 Q.T
#          M: 총 사용자 수
#          N: 총 아이템 수
#          K: 잠재 요인의 차원 수
#          R: M*N 차원의 사용자 - 아이템 평점 행렬
#          P: 사용자와 잠재요인과의 관계값을 가지는 M*K 차원의 사용자-잠재요인 행렬
#          Q: 아이템과 잠재요인과의 관계 값을 가지는 N*K 차원의 아이템-잠재요인 행렬
#          Q.T: Q 매트릭스의 행과 열 값을 교환한 전치행렬

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 확률적 경사 하강법을 이용한 행렬 분해
# : P와 Q 행렬로 계산된 예측 R 행렬값이 실제 R 행렬과 가장 최소의 오류를 가지도록 반복적으로 비용함수 최적화 → P와 Q 유추

# %%
import numpy as np

# 원본 행렬 R 생성, 분해 행렬 P와 Q 초기화, 잠재 요인 차원 K는 3으로 설정.
R = np.array([[4, np.NaN, np.NaN, 2, np.NaN],
              [np.NaN, 5, np.NaN, 3, 1],
              [np.NaN, np.NaN, 3, 4, 4],
              [5, 2, 1, 2, np.NaN]])

num_users, num_items = R.shape
K = 3

# P와 Q 행렬의 크기를 지정하고 정규분포를 가진 임의의 값으로 입력
np.random.seed(1)
P = np.random.normal(scale = 1./K, size = (num_users, K))
Q = np.random.normal(scale = 1./K, size = (num_items, K))

# %%
from sklearn.metrics import mean_squared_error

def get_rmse(R, P, Q, non_zeros):
    error = 0
    # 두 개의 분해된 행렬 P와 Q.T의 내적으로 예측 R 행렬 생성
    full_pred_matrix = np.dot(P,Q.T)

    # 실제 R 행렬에서 널이 아닌 값의 위치 인덱스 추출해 실제 R 행렬과 예측 행렬의 RMSE 추출
    x_non_zero_ind = [non_zero[0] for non_zero in non_zeros]
    y_non_zero_ind = [non_zero[1] for non_zero in non_zeros]
    R_non_zeros = R[x_non_zero_ind, y_non_zero_ind]
    full_pred_matrix_non_zeros = full_pred_matrix[x_non_zero_ind, y_non_zero_ind]
    mse = mean_squared_error(R_non_zeros, full_pred_matrix_non_zeros)
    rmse = np.sqrt(mse)


    return rmse

# %% [markdown]
# - SGD 기반 행렬 분해

# %%
# R > 0인 행 위치, 열 위치, 값을 non_zeros 리스트에 저장.
non_zeros = [ (i, j, R[i, j]) for i in range(num_users) for j in range(num_items) if R[i, j]>0]

steps = 1000
learning_rate = 0.01
r_lambda = 0.01

# SGD 기법으로 P와 Q 매트릭스를 계속 업데이트
for step in range(steps):
    for i, j, r in non_zeros:
        # 실제 값과 예측 값의 차이인 오류 값 구함
        eij = r - np.dot(P[i, :], Q[j, :].T)
        # Regularization을 반영한 SGD 업데이트 공식 적용
        P[i, :] = P[i, :] + learning_rate*(eij * Q[j, :] - r_lambda*P[i,:])
        Q[j, :] = Q[j, :] + learning_rate*(eij * P[i, :] - r_lambda*Q[j,:])

        rmse = get_rmse(R, P, Q, non_zeros)
        if (step % 50) == 0:
            print('### iteration step: ', step, "rmse: ", rmse)
# Out:
# ### iteration step:  0 rmse:  3.2489778594025154
# ### iteration step:  0 rmse:  3.2480990798066887
# ### iteration step:  0 rmse:  3.241464686428762
# ### iteration step:  0 rmse:  3.2396617633439706
# ### iteration step:  0 rmse:  3.239850067854985
# ### iteration step:  0 rmse:  3.2385288670354706
# ### iteration step:  0 rmse:  3.2366133044118723
# ### iteration step:  0 rmse:  3.2348021256776747
# ### iteration step:  0 rmse:  3.2295210104732472
# ### iteration step:  0 rmse:  3.2276749204068773
# ### iteration step:  0 rmse:  3.22778549907869
# ### iteration step:  0 rmse:  3.2264784143295184
# ### iteration step:  50 rmse:  0.5001203401883644
# ### iteration step:  50 rmse:  0.4999347903251159
# ### iteration step:  50 rmse:  0.4989641313165061
# ### iteration step:  50 rmse:  0.4988356634569485
# ### iteration step:  50 rmse:  0.49893407337923934
# ### iteration step:  50 rmse:  0.4983022879656944
# ### iteration step:  50 rmse:  0.4984098557903926
# ### iteration step:  50 rmse:  0.49791517988237466
# ### iteration step:  50 rmse:  0.4898277916713945
# ### iteration step:  50 rmse:  0.48893104180925007
# ### iteration step:  50 rmse:  0.4885493163584219
# ### iteration step:  50 rmse:  0.4874903876549622
# ### iteration step:  100 rmse:  0.16484919469241902
# ### iteration step:  100 rmse:  0.16459039753607962
# ### iteration step:  100 rmse:  0.16454276047899377
# ### iteration step:  100 rmse:  0.1641048553714494
# ### iteration step:  100 rmse:  0.16412472343389245
# ### iteration step:  100 rmse:  0.16409015190818663
# ### iteration step:  100 rmse:  0.16366726922778468
# ### iteration step:  100 rmse:  0.16371430941127607
# ### iteration step:  100 rmse:  0.16303203223303983
# ### iteration step:  100 rmse:  0.16292505485281353
# ### iteration step:  100 rmse:  0.16267755051406885
# ### iteration step:  100 rmse:  0.1621629000013364
# ### iteration step:  150 rmse:  0.08030776244490974
# ### iteration step:  150 rmse:  0.08030743853334367
# ### iteration step:  150 rmse:  0.08030167800129918
# ### iteration step:  150 rmse:  0.08002248140992611
# ### iteration step:  150 rmse:  0.08006047672626584
# ### iteration step:  150 rmse:  0.08009509113086173
# ### iteration step:  150 rmse:  0.07976243860493047
# ### iteration step:  150 rmse:  0.07980419454609289
# ### iteration step:  150 rmse:  0.07946806991853171
# ### iteration step:  150 rmse:  0.0794811070608678
# ### iteration step:  150 rmse:  0.07947642684432867
# ### iteration step:  150 rmse:  0.07934845835004936
# ### iteration step:  200 rmse:  0.04705216829014222
# ### iteration step:  200 rmse:  0.047140101122592475
# ### iteration step:  200 rmse:  0.04712922014044616
# ### iteration step:  200 rmse:  0.04691062431976472
# ### iteration step:  200 rmse:  0.04696349168276925
# ### iteration step:  200 rmse:  0.04702184923441078
# ### iteration step:  200 rmse:  0.046735385528561754
# ### iteration step:  200 rmse:  0.046759499139243474
# ### iteration step:  200 rmse:  0.046509478883679456
# ### iteration step:  200 rmse:  0.046533343732467605
# ### iteration step:  200 rmse:  0.046536947956032394
# ### iteration step:  200 rmse:  0.04664294171134511
# ### iteration step:  250 rmse:  0.03174074791314368
# ### iteration step:  250 rmse:  0.031862445189900404
# ### iteration step:  250 rmse:  0.03183021178593951
# ### iteration step:  250 rmse:  0.03164929542204128
# ### iteration step:  250 rmse:  0.03171855871475334
# ### iteration step:  250 rmse:  0.031782547142829506
# ### iteration step:  250 rmse:  0.03151746412915386
# ### iteration step:  250 rmse:  0.03152579709452046
# ### iteration step:  250 rmse:  0.031289098447622885
# ### iteration step:  250 rmse:  0.03132802613727242
# ### iteration step:  250 rmse:  0.031330330160538614
# ### iteration step:  250 rmse:  0.03154678105397649
# ### iteration step:  300 rmse:  0.02424535190622712
# ### iteration step:  300 rmse:  0.02437741246966857
# ### iteration step:  300 rmse:  0.02431774791852384
# ### iteration step:  300 rmse:  0.024165235608113782
# ### iteration step:  300 rmse:  0.024249762300659165
# ### iteration step:  300 rmse:  0.024308929666874913
# ### iteration step:  300 rmse:  0.024059378848331685
# ### iteration step:  300 rmse:  0.024056771160642983
# ### iteration step:  300 rmse:  0.023805532641036832
# ### iteration step:  300 rmse:  0.023866627292474955
# ### iteration step:  300 rmse:  0.023885105364392797
# ### iteration step:  300 rmse:  0.02414773810421995
# ### iteration step:  350 rmse:  0.020587853164405336
# ### iteration step:  350 rmse:  0.020718622886748226
# ### iteration step:  350 rmse:  0.020634253458712174
# ### iteration step:  350 rmse:  0.0205043398321098
# ### iteration step:  350 rmse:  0.020600088917470713
# ### iteration step:  350 rmse:  0.020649328777438167
# ### iteration step:  350 rmse:  0.020415331938372423
# ### iteration step:  350 rmse:  0.020405925622653524
# ### iteration step:  350 rmse:  0.02013486205003262
# ### iteration step:  350 rmse:  0.020217084009966677
# ### iteration step:  350 rmse:  0.020256053291739032
# ### iteration step:  350 rmse:  0.020532840829073182
# ### iteration step:  400 rmse:  0.018817119939500422
# ### iteration step:  400 rmse:  0.018941840944066497
# ### iteration step:  400 rmse:  0.01883956054834233
# ### iteration step:  400 rmse:  0.01872656009328641
# ### iteration step:  400 rmse:  0.018829129667786593
# ### iteration step:  400 rmse:  0.018868204536045718
# ### iteration step:  400 rmse:  0.018648738338345024
# ### iteration step:  400 rmse:  0.018635395540854447
# ### iteration step:  400 rmse:  0.018348668829400228
# ### iteration step:  400 rmse:  0.018446480602687217
# ### iteration step:  400 rmse:  0.018501718059552783
# ### iteration step:  400 rmse:  0.018778928211681367
# ### iteration step:  450 rmse:  0.01794360046054276
# ### iteration step:  450 rmse:  0.018061529177598016
# ### iteration step:  450 rmse:  0.01794763353426029
# ### iteration step:  450 rmse:  0.017846349400458927
# ### iteration step:  450 rmse:  0.017952703791524013
# ### iteration step:  450 rmse:  0.017983733086679804
# ### iteration step:  450 rmse:  0.01777598904622009
# ### iteration step:  450 rmse:  0.017760379241955438
# ### iteration step:  450 rmse:  0.01746319865263801
# ### iteration step:  450 rmse:  0.017571149316308054
# ### iteration step:  450 rmse:  0.01763717043425347
# ### iteration step:  450 rmse:  0.01791087167991849
# ### iteration step:  500 rmse:  0.017492073055781772
# ### iteration step:  500 rmse:  0.017604054788416153
# ### iteration step:  500 rmse:  0.017482880131434272
# ### iteration step:  500 rmse:  0.017389380463276267
# ### iteration step:  500 rmse:  0.017497837523766196
# ### iteration step:  500 rmse:  0.0175232125938391
# ### iteration step:  500 rmse:  0.017324074268729894
# ### iteration step:  500 rmse:  0.01730707892757623
# ### iteration step:  500 rmse:  0.017003148801008432
# ### iteration step:  500 rmse:  0.017117435335763903
# ### iteration step:  500 rmse:  0.017190170154711283
# ### iteration step:  500 rmse:  0.017460296642977522
# ### iteration step:  550 rmse:  0.017242253427607965
# ### iteration step:  550 rmse:  0.0173494403785737
# ### iteration step:  550 rmse:  0.01722364250058833
# ### iteration step:  550 rmse:  0.017135301665381644
# ### iteration step:  550 rmse:  0.017245003108834707
# ### iteration step:  550 rmse:  0.017266601005350893
# ### iteration step:  550 rmse:  0.017073522939837393
# ### iteration step:  550 rmse:  0.017055598116733503
# ### iteration step:  550 rmse:  0.016747201809170578
# ### iteration step:  550 rmse:  0.016865489778033194
# ### iteration step:  550 rmse:  0.016942382743487364
# ### iteration step:  550 rmse:  0.01720980965265675
# ### iteration step:  600 rmse:  0.017091630480399703
# ### iteration step:  600 rmse:  0.01719503547178962
# ### iteration step:  600 rmse:  0.01706617240169974
# ### iteration step:  600 rmse:  0.01698135105986765
# ### iteration step:  600 rmse:  0.01709186385067901
# ### iteration step:  600 rmse:  0.017110972825716563
# ### iteration step:  600 rmse:  0.016922130628790895
# ### iteration step:  600 rmse:  0.016903520434462773
# ### iteration step:  600 rmse:  0.016592036177330283
# ### iteration step:  600 rmse:  0.016712955220557983
# ### iteration step:  600 rmse:  0.016792489510550117
# ### iteration step:  600 rmse:  0.017058031602187468
# ### iteration step:  650 rmse:  0.016991150801097917
# ### iteration step:  650 rmse:  0.01709156227116152
# ### iteration step:  650 rmse:  0.016960536264086938
# ### iteration step:  650 rmse:  0.01687824605201077
# ### iteration step:  650 rmse:  0.016989347258625657
# ### iteration step:  650 rmse:  0.017006801540033784
# ### iteration step:  650 rmse:  0.016820958628848342
# ### iteration step:  650 rmse:  0.016801802093481363
# ### iteration step:  650 rmse:  0.01648808141511084
# ### iteration step:  650 rmse:  0.01661083644997907
# ### iteration step:  650 rmse:  0.016692125802083704
# ### iteration step:  650 rmse:  0.01695633020741451
# ### iteration step:  700 rmse:  0.016916519111718376
# ### iteration step:  700 rmse:  0.01701452860860646
# ### iteration step:  700 rmse:  0.016881861447685297
# ### iteration step:  700 rmse:  0.0168015173434834
# ### iteration step:  700 rmse:  0.01691308858035668
# ### iteration step:  700 rmse:  0.016929415350843482
# ### iteration step:  700 rmse:  0.01674574937592772
# ### iteration step:  700 rmse:  0.01672613157012921
# ### iteration step:  700 rmse:  0.016410720943022178
# ### iteration step:  700 rmse:  0.016534850253555857
# ### iteration step:  700 rmse:  0.01661737722276413
# ### iteration step:  700 rmse:  0.016880556106418625
# ### iteration step:  750 rmse:  0.016855338480905122
# ### iteration step:  750 rmse:  0.016951388580730944
# ### iteration step:  750 rmse:  0.01681738315718971
# ### iteration step:  750 rmse:  0.016738642108352436
# ### iteration step:  750 rmse:  0.016850618324241506
# ### iteration step:  750 rmse:  0.016866148559170648
# ### iteration step:  750 rmse:  0.016684111951139363
# ### iteration step:  750 rmse:  0.01666408870483783
# ### iteration step:  750 rmse:  0.016347353809655386
# ### iteration step:  750 rmse:  0.01647258752866665
# ### iteration step:  750 rmse:  0.016556048427203603
# ### iteration step:  750 rmse:  0.016818353970197947
# ### iteration step:  800 rmse:  0.016801156950802587
# ### iteration step:  800 rmse:  0.016895582957507444
# ### iteration step:  800 rmse:  0.016760416541263885
# ### iteration step:  800 rmse:  0.016683077964833756
# ### iteration step:  800 rmse:  0.016795422061069456
# ### iteration step:  800 rmse:  0.01681036462443067
# ### iteration step:  800 rmse:  0.016629587728585374
# ### iteration step:  800 rmse:  0.016609198030725494
# ### iteration step:  800 rmse:  0.016291394093234438
# ### iteration step:  800 rmse:  0.01641757269657466
# ### iteration step:  800 rmse:  0.016501787648563984
# ### iteration step:  800 rmse:  0.016763274986163302
# ### iteration step:  850 rmse:  0.016750591215954763
# ### iteration step:  850 rmse:  0.01684365206399585
# ### iteration step:  850 rmse:  0.01670742999285566
# ### iteration step:  850 rmse:  0.016631376077175353
# ### iteration step:  850 rmse:  0.016744065938434156
# ### iteration step:  850 rmse:  0.016758554592130926
# ### iteration step:  850 rmse:  0.01657878231987261
# ### iteration step:  850 rmse:  0.016558054839448437
# ### iteration step:  850 rmse:  0.01623936743386035
# ### iteration step:  850 rmse:  0.016366394850155622
# ### iteration step:  850 rmse:  0.01645125576011755
# ### iteration step:  850 rmse:  0.01671192585737461
# ### iteration step:  900 rmse:  0.01670187867134629
# ### iteration step:  900 rmse:  0.016793778552459004
# ### iteration step:  900 rmse:  0.016656565160243
# ### iteration step:  900 rmse:  0.01658172558020058
# ### iteration step:  900 rmse:  0.01669474725468697
# ### iteration step:  900 rmse:  0.0167088697456985
# ### iteration step:  900 rmse:  0.01652992120989446
# ### iteration step:  900 rmse:  0.016508877902924976
# ### iteration step:  900 rmse:  0.016189447260049755
# ### iteration step:  900 rmse:  0.01631726382961783
# ### iteration step:  900 rmse:  0.016402704216524726
# ### iteration step:  900 rmse:  0.016662530539226485
# ### iteration step:  950 rmse:  0.01665412368231172
# ### iteration step:  950 rmse:  0.016745026905147824
# ### iteration step:  950 rmse:  0.016606863347619072
# ### iteration step:  950 rmse:  0.016533194611074838
# ### iteration step:  950 rmse:  0.01664653864177951
# ### iteration step:  950 rmse:  0.016660354483604162
# ### iteration step:  950 rmse:  0.016482097509939495
# ### iteration step:  950 rmse:  0.016460755719160697
# ### iteration step:  950 rmse:  0.016140691579359066
# ### iteration step:  950 rmse:  0.01626925842736098
# ### iteration step:  950 rmse:  0.01635523589049881
# ### iteration step:  950 rmse:  0.016614180109517738

# %%
pred_matrix = np.dot(P, Q.T)
print('예측 행렬:\n', np.round(pred_matrix, 3))
# Out:
# 예측 행렬:
#  [[3.99  0.738 1.359 2.003 1.758]
#  [6.603 4.978 0.95  2.98  1.003]
#  [6.954 0.475 2.987 3.977 3.986]
#  [4.968 2.004 1.007 2.018 1.171]]
